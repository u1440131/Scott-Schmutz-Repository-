# %% [markdown]
# # IS 4487 Assignment 11: Predicting Airbnb Prices with Regression
#
# In this assignment, you will:
# - Load the Airbnb dataset you cleaned and transformed in Assignment 7
# - Build a linear regression model to predict listing price
# - Interpret which features most affect price
# - Try to improve your model using only the most impactful predictors
# - Practice explaining your findings to a business audience like a host, pricing strategist, or city partner
#
# ## Why This Matters
#
# Pricing is one of the most important levers for hosts and Airbnb’s business teams. Understanding what drives price — and being able to predict it accurately — helps improve search results, revenue management, and guest satisfaction.
#
# This assignment gives you hands-on practice turning a cleaned dataset into a predictive model. You’ll focus not just on code, but on what the results mean and how you’d communicate them to stakeholders.
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Assignments/assignment_11_regression.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Original Source: Dataset Description
#
# The dataset you'll be using is a **detailed Airbnb listing file**, available from [Inside Airbnb](https://insideairbnb.com/get-the-data/).
#
# Each row represents one property listing. The columns include:
#
# - **Host attributes** (e.g., host ID, host name, host response time)
# - **Listing details** (e.g., price, room type, minimum nights, availability)
# - **Location data** (e.g., neighborhood, latitude/longitude)
# - **Property characteristics** (e.g., number of bedrooms, amenities, accommodates)
# - **Calendar/booking variables** (e.g., last review date, number of reviews)
#
# The schema is consistent across cities, so you can expect similar columns regardless of the location you choose.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## 1. Load Your Transformed Airbnb Dataset
#
# **Business framing:**
# Before building any models, we must start with clean, prepared data. In Assignment 7, you exported a cleaned version of your Airbnb dataset. You’ll now import that file for analysis.
#
# ### Do the following:
# - Import your CSV file called `cleaned_airbnb_data_7.csv`.   (Note: If you had significant errors with assignment 7, you can use the file named "airbnb_listings.csv" in the DataSets folder on GitHub as a backup starting point.)
# - Use `pandas` to load and preview the dataset
#
# ### In Your Response:
# 1. What does the dataset include?
# 2. How many rows and columns are present?

# %%
# Out:
# The dataset has 459 rows and 84 columns.
#         id                           listing_url       scrape_id last_scraped  \
# 0  2992450  https://www.airbnb.com/rooms/2992450  20250804133828   2025-08-04
# 1  3820211  https://www.airbnb.com/rooms/3820211  20250804133828   2025-08-04
# 2  5651579  https://www.airbnb.com/rooms/5651579  20250804133828   2025-08-04
# 3  6623339  https://www.airbnb.com/rooms/6623339  20250804133828   2025-08-04
# 4  9005989  https://www.airbnb.com/rooms/9005989  20250804133828   2025-08-04
#
#         source                                               name  \
# 0  city scrape                         Luxury 2 bedroom apartment
# 1  city scrape  Funky Urban Gem: Prime Central Location - Park...
# 2  city scrape         Large studio apt  by Capital Center & ESP@
# 3  city scrape  Bright & Cozy City Stay · Top Location + Parking!
# 4  city scrape     Studio in The heart of Center SQ, in Albany NY
#
#                                          description  \
# 0  The apartment is located in a quiet neighborho...
# 1  Step into the charming and comfy 1BR/1BA apart...
# 2  Spacious studio with hardwood floors, fully eq...
# 3  Step into the charming and comfy 1BR/1BA apart...
# 4  (21 years of age or older ONLY) NON- SMOKING.....
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Overview<br /><br />The lovely apartment is lo...
# 2  The neighborhood is very eclectic. We have a v...
# 3  Overview<br /><br />The lovely apartment is lo...
# 4  There are many shops, restaurants, bars, museu...
#
#                                      host_url host_name  ...  \
# 0   https://www.airbnb.com/users/show/4621559   Kenneth  ...
# 1  https://www.airbnb.com/users/show/19648678     Terra  ...
# 2  https://www.airbnb.com/users/show/29288920     Gregg  ...
# 3  https://www.airbnb.com/users/show/19648678     Terra  ...
# 4  https://www.airbnb.com/users/show/17766924     Sugey  ...
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              0.07
# 1                                           0              2.32
# 2                                           0              2.97
# 3                                           0              2.68
# 4                                           0              5.67
#
#   log_transformed_review_scores_communication  \
# 0                                    1.715598
# 1                                    1.759581
# 2                                    1.771557
# 3                                    1.740466
# 4                                    1.780024
#
#   minmax_scaled_review_scores_value zscore_scaled_reviews_per_month  \
# 0                            0.6675                       -0.986024
# 1                            0.9425                        0.171292
# 2                            0.9100                        0.505628
# 3                            0.9300                        0.356463
# 4                            0.9425                        1.894407
#
#   review_scores_location_category price_per_night high_reviews_per_month_flag  \
# 0                             Low             2.5                           0
# 1                            High            52.0                           0
# 2                            High            37.5                           0
# 3                            High            50.5                           0
# 4                            High           110.0                           0
#
#   neighborhood_Neighborhood highlights
# 0                                False
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True
#
# [5 rows x 84 columns]

# %% [markdown]
# The dataset includes information about Airbnb bookings and properties, such as price per night, location, host, and number of reviews. It appears to be quite a comprehensive dataset with a lot of valuable information. Some variables in here are MinMax Scaled or Log Transformed.
#
#
# There are 459 rows and 84 columns in this dataset.

# %% [markdown]
# ## 2. Drop Columns Not Useful for Modeling
#
# **Business framing:**
# Some columns — like post IDs or text — may not help us predict price and could add noise or bias.
#
# ### Do the following:
# - Drop columns like `post_id`, `title`, `descr`, `details`, and `address` if they’re still in your dataset
#
# ### In Your Response:
# 1. What columns did you drop, and why?
# 2. What risks might occur if you included them in your model?

# %%
# Out:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy', 'number_of_reviews_ly', 'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'license', 'instant_bookable', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month', 'log_transformed_review_scores_communication', 'minmax_scaled_review_scores_value', 'zscore_scaled_reviews_per_month', 'review_scores_location_category', 'price_per_night', 'high_reviews_per_month_flag', 'neighborhood_Neighborhood highlights']

# %%
# Out:
# The dataset now has 459 rows and 73 columns after dropping columns.

# %% [markdown]
# I dropped the following columns from the dataset: id, description, listing_url, scrape_id, neighborhood_overview, host_about, host_picture_url, name, source, host_name, host_thumbnail_url. I dropped these columns because they would be useless in a regression analysis. They were either meaningless numbers such as ID's, or text descriptions that would not help with regression. URL addresses are also not helpful for regression.
#
#
# Including things like ID numbers in a regression model introduces the risk of overfitting, or the model memorizing outcomes associated with specific ID's. Things like ID numbers and URL's also have no predictive significance at all, so including them in a regression model is useless. It is best practice to remove these items before beginning analysis for those reasons.

# %% [markdown]
# ## 3. Explore Relationships Between Numeric Features
#
# **Business framing:**
# Understanding how features relate to each other — and to the target — helps guide feature selection and modeling.
#
# ### Do the following:
# - Generate a correlation matrix
# - Identify which variables are strongly related to `price`
#
# ### In Your Response:
# 1. Which variables had the strongest positive or negative correlation with price?
# 2. Which variables might be useful predictors?

# %%
# Out:
#                                               host_listings_count  \
# host_listings_count                                      1.000000
# host_total_listings_count                                0.973960
# latitude                                                -0.070382
# longitude                                                0.111195
# accommodates                                             0.037236
# bathrooms                                               -0.050743
# bedrooms                                                 0.041395
# beds                                                     0.057712
# price                                                   -0.014677
# minimum_nights                                           0.034032
# maximum_nights                                           0.166138
# minimum_minimum_nights                                   0.028531
# maximum_minimum_nights                                   0.040723
# minimum_maximum_nights                                   0.170092
# maximum_maximum_nights                                   0.162880
# minimum_nights_avg_ntm                                   0.037307
# maximum_nights_avg_ntm                                   0.165437
# availability_30                                         -0.092245
# availability_60                                         -0.088553
# availability_90                                         -0.084015
# availability_365                                         0.005216
# number_of_reviews                                       -0.073677
# number_of_reviews_ltm                                   -0.094938
# number_of_reviews_l30d                                  -0.106978
# availability_eoy                                        -0.057619
# number_of_reviews_ly                                    -0.083752
# estimated_occupancy_l365d                               -0.075741
# estimated_revenue_l365d                                 -0.073785
# review_scores_rating                                    -0.277218
# review_scores_accuracy                                  -0.245742
# review_scores_cleanliness                               -0.262715
# review_scores_checkin                                   -0.248577
# review_scores_communication                             -0.341142
# review_scores_location                                  -0.241995
# review_scores_value                                     -0.375941
# license                                                       NaN
# instant_bookable                                         0.277760
# calculated_host_listings_count                           0.015981
# calculated_host_listings_count_entire_homes              0.057724
# calculated_host_listings_count_private_rooms            -0.061563
# calculated_host_listings_count_shared_rooms                   NaN
# reviews_per_month                                       -0.116031
# log_transformed_review_scores_communication             -0.351926
# minmax_scaled_review_scores_value                       -0.375941
# zscore_scaled_reviews_per_month                         -0.116031
# price_per_night                                         -0.060832
# high_reviews_per_month_flag                             -0.012745
# neighborhood_Neighborhood highlights                     0.176851
#
#                                               host_total_listings_count  \
# host_listings_count                                            0.973960
# host_total_listings_count                                      1.000000
# latitude                                                      -0.072907
# longitude                                                      0.099717
# accommodates                                                   0.057426
# bathrooms                                                     -0.044631
# bedrooms                                                       0.061755
# beds                                                           0.086508
# price                                                         -0.006580
# minimum_nights                                                 0.005437
# maximum_nights                                                 0.178693
# minimum_minimum_nights                                         0.004440
# maximum_minimum_nights                                         0.011593
# minimum_maximum_nights                                         0.155061
# maximum_maximum_nights                                         0.148242
# minimum_nights_avg_ntm                                         0.007888
# maximum_nights_avg_ntm                                         0.150498
# availability_30                                               -0.076722
# availability_60                                               -0.079887
# availability_90                                               -0.082325
# availability_365                                              -0.002250
# number_of_reviews                                             -0.065519
# number_of_reviews_ltm                                         -0.086009
# number_of_reviews_l30d                                        -0.096769
# availability_eoy                                              -0.060922
# number_of_reviews_ly                                          -0.074168
# estimated_occupancy_l365d                                     -0.087398
# estimated_revenue_l365d                                       -0.077644
# review_scores_rating                                          -0.232830
# review_scores_accuracy                                        -0.252180
# review_scores_cleanliness                                     -0.226066
# review_scores_checkin                                         -0.205193
# review_scores_communication                                   -0.302003
# review_scores_location                                        -0.212705
# review_scores_value                                           -0.304869
# license                                                             NaN
# instant_bookable                                               0.252688
# calculated_host_listings_count                                 0.007070
# calculated_host_listings_count_entire_homes                    0.048405
# calculated_host_listings_count_private_rooms                  -0.062113
# calculated_host_listings_count_shared_rooms                         NaN
# reviews_per_month                                             -0.103788
# log_transformed_review_scores_communication                   -0.311565
# minmax_scaled_review_scores_value                             -0.304869
# zscore_scaled_reviews_per_month                               -0.103788
# price_per_night                                               -0.047459
# high_reviews_per_month_flag                                   -0.010989
# neighborhood_Neighborhood highlights                           0.160677
#
#                                               latitude  longitude  \
# host_listings_count                          -0.070382   0.111195
# host_total_listings_count                    -0.072907   0.099717
# latitude                                      1.000000  -0.548236
# longitude                                    -0.548236   1.000000
# accommodates                                  0.006482  -0.083466
# bathrooms                                     0.067394  -0.175493
# bedrooms                                      0.016919  -0.215899
# beds                                          0.021012  -0.138303
# price                                        -0.014666  -0.118913
# minimum_nights                                0.146688  -0.120240
# maximum_nights                               -0.099903  -0.006670
# minimum_minimum_nights                        0.148301  -0.104022
# maximum_minimum_nights                        0.146927  -0.107650
# minimum_maximum_nights                       -0.157716   0.012963
# maximum_maximum_nights                       -0.176282   0.016770
# minimum_nights_avg_ntm                        0.149106  -0.109626
# maximum_nights_avg_ntm                       -0.166367   0.018353
# availability_30                               0.084141   0.055739
# availability_60                               0.135308   0.004010
# availability_90                               0.162220  -0.037874
# availability_365                              0.122732  -0.068418
# number_of_reviews                            -0.144131   0.031902
# number_of_reviews_ltm                        -0.129025  -0.028313
# number_of_reviews_l30d                       -0.064483  -0.031804
# availability_eoy                              0.138809  -0.052914
# number_of_reviews_ly                         -0.109899  -0.038312
# estimated_occupancy_l365d                    -0.117630  -0.041611
# estimated_revenue_l365d                      -0.088685  -0.147798
# review_scores_rating                          0.082463  -0.228211
# review_scores_accuracy                        0.005892  -0.205039
# review_scores_cleanliness                     0.106954  -0.230449
# review_scores_checkin                         0.036571  -0.185848
# review_scores_communication                   0.101162  -0.166284
# review_scores_location                        0.108243  -0.332212
# review_scores_value                           0.066316  -0.214617
# license                                            NaN        NaN
# instant_bookable                              0.091104   0.043940
# calculated_host_listings_count                0.120997  -0.047019
# calculated_host_listings_count_entire_homes  -0.017696   0.109600
# calculated_host_listings_count_private_rooms  0.227452  -0.245058
# calculated_host_listings_count_shared_rooms        NaN        NaN
# reviews_per_month                            -0.119777   0.045170
# log_transformed_review_scores_communication   0.096122  -0.158498
# minmax_scaled_review_scores_value             0.066316  -0.214617
# zscore_scaled_reviews_per_month              -0.119777   0.045170
# price_per_night                              -0.043658  -0.021484
# high_reviews_per_month_flag                  -0.034922   0.047118
# neighborhood_Neighborhood highlights         -0.098618   0.059345
#
#                                               accommodates  bathrooms  \
# host_listings_count                               0.037236  -0.050743
# host_total_listings_count                         0.057426  -0.044631
# latitude                                          0.006482   0.067394
# longitude                                        -0.083466  -0.175493
# accommodates                                      1.000000   0.520394
# bathrooms                                         0.520394   1.000000
# bedrooms                                          0.809299   0.534375
# beds                                              0.828875   0.462908
# price                                             0.579588   0.468030
# minimum_nights                                   -0.117221  -0.065774
# maximum_nights                                    0.056143  -0.047593
# minimum_minimum_nights                           -0.106866  -0.056712
# maximum_minimum_nights                           -0.099042  -0.063469
# minimum_maximum_nights                            0.174628   0.085153
# maximum_maximum_nights                            0.192736   0.105022
# minimum_nights_avg_ntm                           -0.104293  -0.063241
# maximum_nights_avg_ntm                            0.177542   0.084541
# availability_30                                   0.048306   0.026756
# availability_60                                   0.016361   0.010900
# availability_90                                  -0.007394  -0.003001
# availability_365                                 -0.007562  -0.025953
# number_of_reviews                                 0.032835  -0.031180
# number_of_reviews_ltm                             0.082221   0.072257
# number_of_reviews_l30d                            0.115183   0.021931
# availability_eoy                                 -0.002242   0.000158
# number_of_reviews_ly                              0.055339   0.065447
# estimated_occupancy_l365d                         0.119119   0.054739
# estimated_revenue_l365d                           0.469373   0.271581
# review_scores_rating                             -0.024135   0.062799
# review_scores_accuracy                           -0.040524   0.057169
# review_scores_cleanliness                        -0.007107   0.068737
# review_scores_checkin                             0.011304   0.042646
# review_scores_communication                       0.018571   0.008527
# review_scores_location                           -0.005875   0.111561
# review_scores_value                               0.009148   0.098843
# license                                                NaN        NaN
# instant_bookable                                  0.014482  -0.018413
# calculated_host_listings_count                   -0.025960   0.020478
# calculated_host_listings_count_entire_homes       0.100762  -0.058583
# calculated_host_listings_count_private_rooms     -0.196689   0.129067
# calculated_host_listings_count_shared_rooms            NaN        NaN
# reviews_per_month                                 0.075746  -0.000851
# log_transformed_review_scores_communication       0.018718   0.010007
# minmax_scaled_review_scores_value                 0.009148   0.098843
# zscore_scaled_reviews_per_month                   0.075746  -0.000851
# price_per_night                                   0.462090   0.395159
# high_reviews_per_month_flag                      -0.025488  -0.024227
# neighborhood_Neighborhood highlights              0.105587   0.004316
#
#                                               bedrooms      beds     price  \
# host_listings_count                           0.041395  0.057712 -0.014677
# host_total_listings_count                     0.061755  0.086508 -0.006580
# latitude                                      0.016919  0.021012 -0.014666
# longitude                                    -0.215899 -0.138303 -0.118913
# accommodates                                  0.809299  0.828875  0.579588
# bathrooms                                     0.534375  0.462908  0.468030
# bedrooms                                      1.000000  0.784348  0.499286
# beds                                          0.784348  1.000000  0.547032
# price                                         0.499286  0.547032  1.000000
# minimum_nights                               -0.073682 -0.132096 -0.075122
# maximum_nights                                0.018216  0.060530  0.017992
# minimum_minimum_nights                       -0.074038 -0.127668 -0.066554
# maximum_minimum_nights                       -0.058222 -0.112134 -0.061523
# minimum_maximum_nights                        0.089088  0.154040  0.112166
# maximum_maximum_nights                        0.108319  0.186677  0.122872
# minimum_nights_avg_ntm                       -0.065479 -0.120936 -0.065831
# maximum_nights_avg_ntm                        0.091417  0.167854  0.111271
# availability_30                              -0.025371  0.027054  0.108409
# availability_60                              -0.048232  0.006436  0.060509
# availability_90                              -0.063985 -0.009935  0.040997
# availability_365                             -0.081974 -0.028767 -0.008559
# number_of_reviews                            -0.086653  0.034481 -0.059924
# number_of_reviews_ltm                        -0.023471  0.075225 -0.049383
# number_of_reviews_l30d                        0.020423  0.107243 -0.024422
# availability_eoy                             -0.085221 -0.006419  0.032537
# number_of_reviews_ly                         -0.034056  0.032964 -0.043521
# estimated_occupancy_l365d                     0.006501  0.087280 -0.049438
# estimated_revenue_l365d                       0.357818  0.381289  0.249488
# review_scores_rating                         -0.014624 -0.049416 -0.028239
# review_scores_accuracy                       -0.062334 -0.069428 -0.020666
# review_scores_cleanliness                     0.021833  0.005422 -0.000918
# review_scores_checkin                        -0.029907 -0.026797 -0.103223
# review_scores_communication                  -0.005564  0.001802 -0.131798
# review_scores_location                       -0.007703 -0.042161 -0.015814
# review_scores_value                           0.016780  0.000307  0.018269
# license                                            NaN       NaN       NaN
# instant_bookable                             -0.033193  0.014030 -0.013742
# calculated_host_listings_count               -0.040207 -0.135324  0.015773
# calculated_host_listings_count_entire_homes   0.018162 -0.057550  0.033206
# calculated_host_listings_count_private_rooms -0.094575 -0.140551 -0.024513
# calculated_host_listings_count_shared_rooms        NaN       NaN       NaN
# reviews_per_month                            -0.049262  0.078050 -0.090843
# log_transformed_review_scores_communication  -0.004458  0.001999 -0.131300
# minmax_scaled_review_scores_value             0.016780  0.000307  0.018269
# zscore_scaled_reviews_per_month              -0.049262  0.078050 -0.090843
# price_per_night                               0.325599  0.394146  0.833960
# high_reviews_per_month_flag                  -0.036005  0.040904 -0.019662
# neighborhood_Neighborhood highlights          0.050272  0.108460  0.071828
#
#                                               minimum_nights  ...  \
# host_listings_count                                 0.034032  ...
# host_total_listings_count                           0.005437  ...
# latitude                                            0.146688  ...
# longitude                                          -0.120240  ...
# accommodates                                       -0.117221  ...
# bathrooms                                          -0.065774  ...
# bedrooms                                           -0.073682  ...
# beds                                               -0.132096  ...
# price                                              -0.075122  ...
# minimum_nights                                      1.000000  ...
# maximum_nights                                     -0.008418  ...
# minimum_minimum_nights                              0.963078  ...
# maximum_minimum_nights                              0.974230  ...
# minimum_maximum_nights                             -0.052935  ...
# maximum_maximum_nights                             -0.065498  ...
# minimum_nights_avg_ntm                              0.975796  ...
# maximum_nights_avg_ntm                             -0.063427  ...
# availability_30                                    -0.081858  ...
# availability_60                                    -0.058469  ...
# availability_90                                    -0.023375  ...
# availability_365                                    0.073427  ...
# number_of_reviews                                  -0.126777  ...
# number_of_reviews_ltm                              -0.173843  ...
# number_of_reviews_l30d                             -0.178401  ...
# availability_eoy                                    0.014510  ...
# number_of_reviews_ly                               -0.149824  ...
# estimated_occupancy_l365d                          -0.132584  ...
# estimated_revenue_l365d                            -0.167670  ...
# review_scores_rating                                0.008843  ...
# review_scores_accuracy                             -0.014682  ...
# review_scores_cleanliness                          -0.059989  ...
# review_scores_checkin                              -0.083556  ...
# review_scores_communication                         0.005171  ...
# review_scores_location                             -0.091679  ...
# review_scores_value                                -0.071429  ...
# license                                                  NaN  ...
# instant_bookable                                   -0.037757  ...
# calculated_host_listings_count                     -0.067989  ...
# calculated_host_listings_count_entire_homes        -0.121811  ...
# calculated_host_listings_count_private_rooms        0.073141  ...
# calculated_host_listings_count_shared_rooms              NaN  ...
# reviews_per_month                                  -0.265131  ...
# log_transformed_review_scores_communication        -0.003105  ...
# minmax_scaled_review_scores_value                  -0.071429  ...
# zscore_scaled_reviews_per_month                    -0.265131  ...
# price_per_night                                    -0.210288  ...
# high_reviews_per_month_flag                        -0.019055  ...
# neighborhood_Neighborhood highlights               -0.120949  ...
#
#                                               calculated_host_listings_count_entire_homes  \
# host_listings_count                                                              0.057724
# host_total_listings_count                                                        0.048405
# latitude                                                                        -0.017696
# longitude                                                                        0.109600
# accommodates                                                                     0.100762
# bathrooms                                                                       -0.058583
# bedrooms                                                                         0.018162
# beds                                                                            -0.057550
# price                                                                            0.033206
# minimum_nights                                                                  -0.121811
# maximum_nights                                                                   0.093624
# minimum_minimum_nights                                                          -0.105391
# maximum_minimum_nights                                                          -0.110128
# minimum_maximum_nights                                                           0.057920
# maximum_maximum_nights                                                           0.066377
# minimum_nights_avg_ntm                                                          -0.112540
# maximum_nights_avg_ntm                                                           0.071935
# availability_30                                                                  0.185405
# availability_60                                                                  0.120375
# availability_90                                                                  0.054084
# availability_365                                                                -0.035279
# number_of_reviews                                                                0.044934
# number_of_reviews_ltm                                                            0.058760
# number_of_reviews_l30d                                                           0.010895
# availability_eoy                                                                 0.002322
# number_of_reviews_ly                                                             0.073523
# estimated_occupancy_l365d                                                        0.090385
# estimated_revenue_l365d                                                          0.098255
# review_scores_rating                                                            -0.049374
# review_scores_accuracy                                                          -0.053887
# review_scores_cleanliness                                                       -0.040696
# review_scores_checkin                                                           -0.013068
# review_scores_communication                                                     -0.045297
# review_scores_location                                                          -0.106625
# review_scores_value                                                             -0.068513
# license                                                                               NaN
# instant_bookable                                                                 0.003628
# calculated_host_listings_count                                                   0.805552
# calculated_host_listings_count_entire_homes                                      1.000000
# calculated_host_listings_count_private_rooms                                    -0.190564
# calculated_host_listings_count_shared_rooms                                           NaN
# reviews_per_month                                                                0.055796
# log_transformed_review_scores_communication                                     -0.035983
# minmax_scaled_review_scores_value                                               -0.068513
# zscore_scaled_reviews_per_month                                                  0.055796
# price_per_night                                                                  0.114243
# high_reviews_per_month_flag                                                     -0.042614
# neighborhood_Neighborhood highlights                                             0.084914
#
#                                               calculated_host_listings_count_private_rooms  \
# host_listings_count                                                              -0.061563
# host_total_listings_count                                                        -0.062113
# latitude                                                                          0.227452
# longitude                                                                        -0.245058
# accommodates                                                                     -0.196689
# bathrooms                                                                         0.129067
# bedrooms                                                                         -0.094575
# beds                                                                             -0.140551
# price                                                                            -0.024513
# minimum_nights                                                                    0.073141
# maximum_nights                                                                   -0.184583
# minimum_minimum_nights                                                            0.061087
# maximum_minimum_nights                                                            0.078397
# minimum_maximum_nights                                                           -0.117165
# maximum_maximum_nights                                                           -0.143055
# minimum_nights_avg_ntm                                                            0.077062
# maximum_nights_avg_ntm                                                           -0.137756
# availability_30                                                                  -0.026176
# availability_60                                                                  -0.006115
# availability_90                                                                   0.032824
# availability_365                                                                 -0.093485
# number_of_reviews                                                                -0.107883
# number_of_reviews_ltm                                                            -0.109138
# number_of_reviews_l30d                                                           -0.158994
# availability_eoy                                                                  0.003892
# number_of_reviews_ly                                                             -0.076495
# estimated_occupancy_l365d                                                        -0.138459
# estimated_revenue_l365d                                                          -0.105717
# review_scores_rating                                                              0.103879
# review_scores_accuracy                                                            0.083435
# review_scores_cleanliness                                                         0.160304
# review_scores_checkin                                                             0.045034
# review_scores_communication                                                      -0.033174
# review_scores_location                                                            0.166025
# review_scores_value                                                               0.056309
# license                                                                                NaN
# instant_bookable                                                                  0.014680
# calculated_host_listings_count                                                    0.428157
# calculated_host_listings_count_entire_homes                                      -0.190564
# calculated_host_listings_count_private_rooms                                      1.000000
# calculated_host_listings_count_shared_rooms                                            NaN
# reviews_per_month                                                                -0.073773
# log_transformed_review_scores_communication                                      -0.036802
# minmax_scaled_review_scores_value                                                 0.056309
# zscore_scaled_reviews_per_month                                                  -0.073773
# price_per_night                                                                  -0.001467
# high_reviews_per_month_flag                                                      -0.033752
# neighborhood_Neighborhood highlights                                             -0.008862
#
#                                               calculated_host_listings_count_shared_rooms  \
# host_listings_count                                                                   NaN
# host_total_listings_count                                                             NaN
# latitude                                                                              NaN
# longitude                                                                             NaN
# accommodates                                                                          NaN
# bathrooms                                                                             NaN
# bedrooms                                                                              NaN
# beds                                                                                  NaN
# price                                                                                 NaN
# minimum_nights                                                                        NaN
# maximum_nights                                                                        NaN
# minimum_minimum_nights                                                                NaN
# maximum_minimum_nights                                                                NaN
# minimum_maximum_nights                                                                NaN
# maximum_maximum_nights                                                                NaN
# minimum_nights_avg_ntm                                                                NaN
# maximum_nights_avg_ntm                                                                NaN
# availability_30                                                                       NaN
# availability_60                                                                       NaN
# availability_90                                                                       NaN
# availability_365                                                                      NaN
# number_of_reviews                                                                     NaN
# number_of_reviews_ltm                                                                 NaN
# number_of_reviews_l30d                                                                NaN
# availability_eoy                                                                      NaN
# number_of_reviews_ly                                                                  NaN
# estimated_occupancy_l365d                                                             NaN
# estimated_revenue_l365d                                                               NaN
# review_scores_rating                                                                  NaN
# review_scores_accuracy                                                                NaN
# review_scores_cleanliness                                                             NaN
# review_scores_checkin                                                                 NaN
# review_scores_communication                                                           NaN
# review_scores_location                                                                NaN
# review_scores_value                                                                   NaN
# license                                                                               NaN
# instant_bookable                                                                      NaN
# calculated_host_listings_count                                                        NaN
# calculated_host_listings_count_entire_homes                                           NaN
# calculated_host_listings_count_private_rooms                                          NaN
# calculated_host_listings_count_shared_rooms                                           NaN
# reviews_per_month                                                                     NaN
# log_transformed_review_scores_communication                                           NaN
# minmax_scaled_review_scores_value                                                     NaN
# zscore_scaled_reviews_per_month                                                       NaN
# price_per_night                                                                       NaN
# high_reviews_per_month_flag                                                           NaN
# neighborhood_Neighborhood highlights                                                  NaN
#
#                                               reviews_per_month  \
# host_listings_count                                   -0.116031
# host_total_listings_count                             -0.103788
# latitude                                              -0.119777
# longitude                                              0.045170
# accommodates                                           0.075746
# bathrooms                                             -0.000851
# bedrooms                                              -0.049262
# beds                                                   0.078050
# price                                                 -0.090843
# minimum_nights                                        -0.265131
# maximum_nights                                        -0.039948
# minimum_minimum_nights                                -0.259625
# maximum_minimum_nights                                -0.259481
# minimum_maximum_nights                                 0.067665
# maximum_maximum_nights                                 0.124721
# minimum_nights_avg_ntm                                -0.264268
# maximum_nights_avg_ntm                                 0.112998
# availability_30                                       -0.011679
# availability_60                                        0.006295
# availability_90                                        0.013499
# availability_365                                       0.032017
# number_of_reviews                                      0.665039
# number_of_reviews_ltm                                  0.854514
# number_of_reviews_l30d                                 0.684999
# availability_eoy                                       0.037084
# number_of_reviews_ly                                   0.732201
# estimated_occupancy_l365d                              0.725115
# estimated_revenue_l365d                                0.526952
# review_scores_rating                                   0.182549
# review_scores_accuracy                                 0.175695
# review_scores_cleanliness                              0.158384
# review_scores_checkin                                  0.165813
# review_scores_communication                            0.176047
# review_scores_location                                 0.131795
# review_scores_value                                    0.200308
# license                                                     NaN
# instant_bookable                                      -0.056654
# calculated_host_listings_count                         0.016427
# calculated_host_listings_count_entire_homes            0.055796
# calculated_host_listings_count_private_rooms          -0.073773
# calculated_host_listings_count_shared_rooms                 NaN
# reviews_per_month                                      1.000000
# log_transformed_review_scores_communication            0.175470
# minmax_scaled_review_scores_value                      0.200308
# zscore_scaled_reviews_per_month                        1.000000
# price_per_night                                        0.077697
# high_reviews_per_month_flag                            0.339053
# neighborhood_Neighborhood highlights                   0.049491
#
#                                               log_transformed_review_scores_communication  \
# host_listings_count                                                             -0.351926
# host_total_listings_count                                                       -0.311565
# latitude                                                                         0.096122
# longitude                                                                       -0.158498
# accommodates                                                                     0.018718
# bathrooms                                                                        0.010007
# bedrooms                                                                        -0.004458
# beds                                                                             0.001999
# price                                                                           -0.131300
# minimum_nights                                                                  -0.003105
# maximum_nights                                                                  -0.015698
# minimum_minimum_nights                                                          -0.027217
# maximum_minimum_nights                                                          -0.025247
# minimum_maximum_nights                                                          -0.044054
# maximum_maximum_nights                                                          -0.049296
# minimum_nights_avg_ntm                                                          -0.024411
# maximum_nights_avg_ntm                                                          -0.040939
# availability_30                                                                 -0.122458
# availability_60                                                                 -0.113171
# availability_90                                                                 -0.101695
# availability_365                                                                -0.003273
# number_of_reviews                                                                0.110626
# number_of_reviews_ltm                                                            0.145498
# number_of_reviews_l30d                                                           0.137933
# availability_eoy                                                                -0.083895
# number_of_reviews_ly                                                             0.138441
# estimated_occupancy_l365d                                                        0.170969
# estimated_revenue_l365d                                                          0.144275
# review_scores_rating                                                             0.779100
# review_scores_accuracy                                                           0.613342
# review_scores_cleanliness                                                        0.444823
# review_scores_checkin                                                            0.694400
# review_scores_communication                                                      0.997826
# review_scores_location                                                           0.359072
# review_scores_value                                                              0.795594
# license                                                                               NaN
# instant_bookable                                                                -0.210877
# calculated_host_listings_count                                                  -0.053310
# calculated_host_listings_count_entire_homes                                     -0.035983
# calculated_host_listings_count_private_rooms                                    -0.036802
# calculated_host_listings_count_shared_rooms                                           NaN
# reviews_per_month                                                                0.175470
# log_transformed_review_scores_communication                                      1.000000
# minmax_scaled_review_scores_value                                                0.795594
# zscore_scaled_reviews_per_month                                                  0.175470
# price_per_night                                                                 -0.154832
# high_reviews_per_month_flag                                                      0.026182
# neighborhood_Neighborhood highlights                                            -0.086234
#
#                                               minmax_scaled_review_scores_value  \
# host_listings_count                                                   -0.375941
# host_total_listings_count                                             -0.304869
# latitude                                                               0.066316
# longitude                                                             -0.214617
# accommodates                                                           0.009148
# bathrooms                                                              0.098843
# bedrooms                                                               0.016780
# beds                                                                   0.000307
# price                                                                  0.018269
# minimum_nights                                                        -0.071429
# maximum_nights                                                        -0.010976
# minimum_minimum_nights                                                -0.110090
# maximum_minimum_nights                                                -0.103703
# minimum_maximum_nights                                                -0.007855
# maximum_maximum_nights                                                -0.014617
# minimum_nights_avg_ntm                                                -0.102288
# maximum_nights_avg_ntm                                                -0.011105
# availability_30                                                       -0.068904
# availability_60                                                       -0.063663
# availability_90                                                       -0.058851
# availability_365                                                      -0.027748
# number_of_reviews                                                      0.144801
# number_of_reviews_ltm                                                  0.182526
# number_of_reviews_l30d                                                 0.144718
# availability_eoy                                                      -0.055118
# number_of_reviews_ly                                                   0.179812
# estimated_occupancy_l365d                                              0.189927
# estimated_revenue_l365d                                                0.169294
# review_scores_rating                                                   0.911012
# review_scores_accuracy                                                 0.717092
# review_scores_cleanliness                                              0.592893
# review_scores_checkin                                                  0.760955
# review_scores_communication                                            0.791610
# review_scores_location                                                 0.490312
# review_scores_value                                                    1.000000
# license                                                                     NaN
# instant_bookable                                                      -0.202325
# calculated_host_listings_count                                        -0.037523
# calculated_host_listings_count_entire_homes                           -0.068513
# calculated_host_listings_count_private_rooms                           0.056309
# calculated_host_listings_count_shared_rooms                                 NaN
# reviews_per_month                                                      0.200308
# log_transformed_review_scores_communication                            0.795594
# minmax_scaled_review_scores_value                                      1.000000
# zscore_scaled_reviews_per_month                                        0.200308
# price_per_night                                                        0.006249
# high_reviews_per_month_flag                                            0.037626
# neighborhood_Neighborhood highlights                                  -0.045495
#
#                                               zscore_scaled_reviews_per_month  \
# host_listings_count                                                 -0.116031
# host_total_listings_count                                           -0.103788
# latitude                                                            -0.119777
# longitude                                                            0.045170
# accommodates                                                         0.075746
# bathrooms                                                           -0.000851
# bedrooms                                                            -0.049262
# beds                                                                 0.078050
# price                                                               -0.090843
# minimum_nights                                                      -0.265131
# maximum_nights                                                      -0.039948
# minimum_minimum_nights                                              -0.259625
# maximum_minimum_nights                                              -0.259481
# minimum_maximum_nights                                               0.067665
# maximum_maximum_nights                                               0.124721
# minimum_nights_avg_ntm                                              -0.264268
# maximum_nights_avg_ntm                                               0.112998
# availability_30                                                     -0.011679
# availability_60                                                      0.006295
# availability_90                                                      0.013499
# availability_365                                                     0.032017
# number_of_reviews                                                    0.665039
# number_of_reviews_ltm                                                0.854514
# number_of_reviews_l30d                                               0.684999
# availability_eoy                                                     0.037084
# number_of_reviews_ly                                                 0.732201
# estimated_occupancy_l365d                                            0.725115
# estimated_revenue_l365d                                              0.526952
# review_scores_rating                                                 0.182549
# review_scores_accuracy                                               0.175695
# review_scores_cleanliness                                            0.158384
# review_scores_checkin                                                0.165813
# review_scores_communication                                          0.176047
# review_scores_location                                               0.131795
# review_scores_value                                                  0.200308
# license                                                                   NaN
# instant_bookable                                                    -0.056654
# calculated_host_listings_count                                       0.016427
# calculated_host_listings_count_entire_homes                          0.055796
# calculated_host_listings_count_private_rooms                        -0.073773
# calculated_host_listings_count_shared_rooms                               NaN
# reviews_per_month                                                    1.000000
# log_transformed_review_scores_communication                          0.175470
# minmax_scaled_review_scores_value                                    0.200308
# zscore_scaled_reviews_per_month                                      1.000000
# price_per_night                                                      0.077697
# high_reviews_per_month_flag                                          0.339053
# neighborhood_Neighborhood highlights                                 0.049491
#
#                                               price_per_night  \
# host_listings_count                                 -0.060832
# host_total_listings_count                           -0.047459
# latitude                                            -0.043658
# longitude                                           -0.021484
# accommodates                                         0.462090
# bathrooms                                            0.395159
# bedrooms                                             0.325599
# beds                                                 0.394146
# price                                                0.833960
# minimum_nights                                      -0.210288
# maximum_nights                                       0.018465
# minimum_minimum_nights                              -0.186690
# maximum_minimum_nights                              -0.198488
# minimum_maximum_nights                               0.130795
# maximum_maximum_nights                               0.146500
# minimum_nights_avg_ntm                              -0.200528
# maximum_nights_avg_ntm                               0.136646
# availability_30                                      0.156168
# availability_60                                      0.106256
# availability_90                                      0.075705
# availability_365                                     0.011304
# number_of_reviews                                    0.059751
# number_of_reviews_ltm                                0.116678
# number_of_reviews_l30d                               0.138573
# availability_eoy                                     0.074597
# number_of_reviews_ly                                 0.100883
# estimated_occupancy_l365d                            0.080549
# estimated_revenue_l365d                              0.281674
# review_scores_rating                                -0.065723
# review_scores_accuracy                              -0.046077
# review_scores_cleanliness                            0.001299
# review_scores_checkin                               -0.097158
# review_scores_communication                         -0.157824
# review_scores_location                              -0.025278
# review_scores_value                                  0.006249
# license                                                   NaN
# instant_bookable                                     0.051396
# calculated_host_listings_count                       0.104283
# calculated_host_listings_count_entire_homes          0.114243
# calculated_host_listings_count_private_rooms        -0.001467
# calculated_host_listings_count_shared_rooms               NaN
# reviews_per_month                                    0.077697
# log_transformed_review_scores_communication         -0.154832
# minmax_scaled_review_scores_value                    0.006249
# zscore_scaled_reviews_per_month                      0.077697
# price_per_night                                      1.000000
# high_reviews_per_month_flag                          0.008932
# neighborhood_Neighborhood highlights                 0.109613
#
#                                               high_reviews_per_month_flag  \
# host_listings_count                                             -0.012745
# host_total_listings_count                                       -0.010989
# latitude                                                        -0.034922
# longitude                                                        0.047118
# accommodates                                                    -0.025488
# bathrooms                                                       -0.024227
# bedrooms                                                        -0.036005
# beds                                                             0.040904
# price                                                           -0.019662
# minimum_nights                                                  -0.019055
# maximum_nights                                                   0.105537
# minimum_minimum_nights                                          -0.017038
# maximum_minimum_nights                                          -0.019477
# minimum_maximum_nights                                          -0.010820
# maximum_maximum_nights                                           0.071542
# minimum_nights_avg_ntm                                          -0.018972
# maximum_nights_avg_ntm                                           0.062460
# availability_30                                                 -0.047880
# availability_60                                                 -0.036919
# availability_90                                                 -0.022801
# availability_365                                                -0.058775
# number_of_reviews                                                0.297805
# number_of_reviews_ltm                                            0.346770
# number_of_reviews_l30d                                           0.198970
# availability_eoy                                                -0.000868
# number_of_reviews_ly                                             0.266977
# estimated_occupancy_l365d                                        0.133478
# estimated_revenue_l365d                                          0.075756
# review_scores_rating                                             0.030959
# review_scores_accuracy                                           0.033566
# review_scores_cleanliness                                        0.034199
# review_scores_checkin                                            0.027365
# review_scores_communication                                      0.027535
# review_scores_location                                           0.047659
# review_scores_value                                              0.037626
# license                                                               NaN
# instant_bookable                                                -0.036029
# calculated_host_listings_count                                  -0.059602
# calculated_host_listings_count_entire_homes                     -0.042614
# calculated_host_listings_count_private_rooms                    -0.033752
# calculated_host_listings_count_shared_rooms                           NaN
# reviews_per_month                                                0.339053
# log_transformed_review_scores_communication                      0.026182
# minmax_scaled_review_scores_value                                0.037626
# zscore_scaled_reviews_per_month                                  0.339053
# price_per_night                                                  0.008932
# high_reviews_per_month_flag                                      1.000000
# neighborhood_Neighborhood highlights                             0.009761
#
#                                               neighborhood_Neighborhood highlights
# host_listings_count                                                       0.176851
# host_total_listings_count                                                 0.160677
# latitude                                                                 -0.098618
# longitude                                                                 0.059345
# accommodates                                                              0.105587
# bathrooms                                                                 0.004316
# bedrooms                                                                  0.050272
# beds                                                                      0.108460
# price                                                                     0.071828
# minimum_nights                                                           -0.120949
# maximum_nights                                                            0.178848
# minimum_minimum_nights                                                   -0.104096
# maximum_minimum_nights                                                   -0.111304
# minimum_maximum_nights                                                    0.343260
# maximum_maximum_nights                                                    0.331644
# minimum_nights_avg_ntm                                                   -0.113696
# maximum_nights_avg_ntm                                                    0.339339
# availability_30                                                           0.015578
# availability_60                                                           0.016791
# availability_90                                                           0.002457
# availability_365                                                         -0.055177
# number_of_reviews                                                         0.341264
# number_of_reviews_ltm                                                     0.132238
# number_of_reviews_l30d                                                   -0.012452
# availability_eoy                                                         -0.001622
# number_of_reviews_ly                                                      0.260190
# estimated_occupancy_l365d                                                 0.162249
# estimated_revenue_l365d                                                   0.243928
# review_scores_rating                                                     -0.018157
# review_scores_accuracy                                                    0.061603
# review_scores_cleanliness                                                 0.057990
# review_scores_checkin                                                    -0.031390
# review_scores_communication                                              -0.085141
# review_scores_location                                                    0.055586
# review_scores_value                                                      -0.045495
# license                                                                        NaN
# instant_bookable                                                          0.012199
# calculated_host_listings_count                                            0.072821
# calculated_host_listings_count_entire_homes                               0.084914
# calculated_host_listings_count_private_rooms                             -0.008862
# calculated_host_listings_count_shared_rooms                                    NaN
# reviews_per_month                                                         0.049491
# log_transformed_review_scores_communication                              -0.086234
# minmax_scaled_review_scores_value                                        -0.045495
# zscore_scaled_reviews_per_month                                           0.049491
# price_per_night                                                           0.109613
# high_reviews_per_month_flag                                               0.009761
# neighborhood_Neighborhood highlights                                      1.000000
#
# [48 rows x 48 columns]

# %%
# Out:
# price                                           1.000000
# price_per_night                                 0.833960
# accommodates                                    0.579588
# beds                                            0.547032
# bedrooms                                        0.499286
# bathrooms                                       0.468030
# estimated_revenue_l365d                         0.249488
# maximum_maximum_nights                          0.122872
# minimum_maximum_nights                          0.112166
# maximum_nights_avg_ntm                          0.111271
# availability_30                                 0.108409
# neighborhood_Neighborhood highlights            0.071828
# availability_60                                 0.060509
# availability_90                                 0.040997
# calculated_host_listings_count_entire_homes     0.033206
# availability_eoy                                0.032537
# review_scores_value                             0.018269
# minmax_scaled_review_scores_value               0.018269
# maximum_nights                                  0.017992
# calculated_host_listings_count                  0.015773
# review_scores_cleanliness                      -0.000918
# host_total_listings_count                      -0.006580
# availability_365                               -0.008559
# instant_bookable                               -0.013742
# latitude                                       -0.014666
# host_listings_count                            -0.014677
# review_scores_location                         -0.015814
# high_reviews_per_month_flag                    -0.019662
# review_scores_accuracy                         -0.020666
# number_of_reviews_l30d                         -0.024422
# calculated_host_listings_count_private_rooms   -0.024513
# review_scores_rating                           -0.028239
# number_of_reviews_ly                           -0.043521
# number_of_reviews_ltm                          -0.049383
# estimated_occupancy_l365d                      -0.049438
# number_of_reviews                              -0.059924
# maximum_minimum_nights                         -0.061523
# minimum_nights_avg_ntm                         -0.065831
# minimum_minimum_nights                         -0.066554
# minimum_nights                                 -0.075122
# zscore_scaled_reviews_per_month                -0.090843
# reviews_per_month                              -0.090843
# review_scores_checkin                          -0.103223
# longitude                                      -0.118913
# log_transformed_review_scores_communication    -0.131300
# review_scores_communication                    -0.131798
# license                                              NaN
# calculated_host_listings_count_shared_rooms          NaN
# Name: price, dtype: float64

# %% [markdown]
# Price_per_night, accomodates, beds, bedrooms, and bathrooms were all positively correlated with price. The most negatively correlated were review_scores_communication, review_scores_checkin, reviews_per_month, and minimum_nights.
#
#
# Price_per_night, accomodates, beds, bedrooms, and bathrooms would be super useful predictors. These look to be the most correlated with price.

# %% [markdown]
# ## 4. Define Features and Target Variable
#
# **Business framing:**
# To build a regression model, you need to define what you’re predicting (target) and what you’re using to make that prediction (features).
#
# ### Do the following:
# - Set `price` as your target variable
# - Remove `price` from your predictors
#
# ### In Your Response:
# 1. What features are you using?
# 2. Why is this a regression problem and not a classification problem?

# %% [markdown]
# I am using all the features in the dataset except for the ones I dropped, which were mostly URL's and ID's, and price, because this is the target variable. I am excited to use features like price_per_night and beds, because these are very strongly correlated with price. I think they will be great predictors.
#
#
# This is a regression problem, and not a classification problem, because we are trying to predict a number; price. This means it is regression. We are not trying to predict a category or a label, which would be classification. Regression predicts a number, like price.

# %% [markdown]
# ## 5. Split Data into Training and Testing Sets
#
# ### Business framing:
# Splitting your data lets you train a model and test how well it performs on new, unseen data.
#
# ### Do the following:
# - Use `train_test_split()` to split into 80% training, 20% testing

# %% [markdown]
# ## 6. Fit a Linear Regression Model
#
# ### Business framing:
# Linear regression helps you quantify the impact of each feature on price and make predictions for new listings.
#
# ### Do the following:
# - Fit a linear regression model to your training data
# - Use it to predict prices for the test set

# %%
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['license']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['license']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %% [markdown]
# ## 7. Evaluate Model Performance
#
# ### Business framing:
# A good model should make accurate predictions. We’ll use Mean Squared Error (MSE) and R² to evaluate how close our predictions were to the actual prices.
#
# ### Do the following:
# - Print MSE and R² score for your model
#
# ### In Your Response:
# 1. What is your R² score? How well does your model explain price variation?
# 2. Is your MSE large or small? What could you do to improve it?

# %%
# Out:
# Mean Squared Error (MSE): 6611.992369323672
# R-squared (R²) Score: -0.17808359532509344

# %% [markdown]
# My R-squared score is negative, which means that this model is currently worse at predicting than random predictions. This is not good, but it will be improved.
#
# My MSE score is enormous at over 6000. I could base my model off just the top predictors to improve this score considerably.

# %% [markdown]
# ## 8. Interpret Model Coefficients
#
# ### Business framing:
# The regression coefficients tell you how each feature impacts price. This can help Airbnb guide hosts and partners.
#
# ### Do the following:
# - Create a table showing feature names and regression coefficients
# - Sort the table so that the most impactful features are at the top
#
# ### In Your Response:
# 1. Which features increased price the most?
# 2. Were any surprisingly negative?
# 3. What business insight could you draw from this?

# %%
# Out:
#                                          feature   coefficient
# 40   log_transformed_review_scores_communication -1.108126e+03
# 3                                      longitude -4.825443e+02
# 2                                       latitude -3.739682e+02
# 31                   review_scores_communication  1.742625e+02
# 27                          review_scores_rating  3.626915e+01
# 30                         review_scores_checkin -3.493175e+01
# 44                   high_reviews_per_month_flag  3.154842e+01
# 11                        maximum_minimum_nights -2.546970e+01
# 29                     review_scores_cleanliness -2.528003e+01
# 14                        minimum_nights_avg_ntm  2.290085e+01
# 33                           review_scores_value  2.277584e+01
# 28                        review_scores_accuracy  1.893345e+01
# 34                              instant_bookable -1.382723e+01
# 7                                           beds  1.368008e+01
# 5                                      bathrooms  1.070031e+01
# 32                        review_scores_location -7.424824e+00
# 41             minmax_scaled_review_scores_value  5.693959e+00
# 8                                 minimum_nights  4.167216e+00
# 6                                       bedrooms -4.094411e+00
# 4                                   accommodates  3.949484e+00
# 22                        number_of_reviews_l30d -3.609856e+00
# 39                             reviews_per_month -2.901634e+00
# 42               zscore_scaled_reviews_per_month -1.492492e+00
# 10                        minimum_minimum_nights -1.407140e+00
# 37  calculated_host_listings_count_private_rooms -1.281411e+00
# 43                               price_per_night  7.590882e-01
# 35                calculated_host_listings_count -7.196207e-01
# 17                               availability_60 -5.631226e-01
# 36   calculated_host_listings_count_entire_homes  5.617903e-01
# 16                               availability_30  4.786955e-01
# 18                               availability_90  4.778475e-01
# 23                              availability_eoy -1.878058e-01
# 25                     estimated_occupancy_l365d -1.264631e-01
# 21                         number_of_reviews_ltm -1.197593e-01
# 0                            host_listings_count  4.764707e-02
# 19                              availability_365  2.925280e-02
# 1                      host_total_listings_count -1.863758e-02
# 24                          number_of_reviews_ly  1.641867e-02
# 15                        maximum_nights_avg_ntm  1.451944e-02
# 20                             number_of_reviews -5.317836e-03
# 13                        maximum_maximum_nights -4.742278e-03
# 12                        minimum_maximum_nights  1.939703e-03
# 26                       estimated_revenue_l365d  7.694570e-04
# 9                                 maximum_nights  3.778398e-04
# 38   calculated_host_listings_count_shared_rooms  3.501199e-12

# %% [markdown]
# The features that increased price the most looked to be review_scores_communication, review_scores_rating, high_reviews_per_month_flag, minimum_nights_avg_ntm, and review_scores_value.
#
#
# The two features that were surprisingly negative were longitude and latitude. This does not make sense to me.
#
#
# As a business, you could say that high communication scores likely equate to higher prices, as well as higher reviews across the board. More reviews also look to correlate with higher prices. Higher-rated properties look to be more expensive, as review_scores_value is one of the top features that increase price.

# %% [markdown]
# ## 9. Try to Improve the Linear Regression Model
#
# ### Business framing:
# The first version of your model included all available features — but not all features are equally useful. Removing weak or noisy predictors can often improve performance and interpretation.
#
# ### Do the following:
# 1. Choose your top 3–5 features with the strongest absolute coefficients
# 2. Rebuild the regression model using just those features
# 3. Compare MSE and R² between the baseline and refined model
#
# ### In Your Response:
# 1. What features did you keep in the refined model, and why?
# 2. Did model performance improve? Why or why not?
# 3. Which model would you recommend to stakeholders?
# 4. How does this relate to your customized learning outcome you created in canvas?

# %%
mse_refined = mean_squared_error(y_test, y_pred_refined)
r2_refined = r2_score(y_test, y_pred_refined)

print(f"Refined Model Mean Squared Error (MSE): {mse_refined}")
print(f"Refined Model R-squared (R²) Score: {r2_refined}")
# Out:
# Refined Model Mean Squared Error (MSE): 5479.9873083045395
# Refined Model R-squared (R²) Score: 0.023610011945060183

# %% [markdown]
# I kept the top 5 features with the strongest absolute coefficients. I kept these features because they were the most predictive of price, or at least more predictive than my last set of features.
#
#
# The model performance did improve, but marginally. The R-squared score increased to above 0, which is an improvement compared to a negative R-squared score. The MSE score for the refined model dropped by about 1000, which is good. It is still high, but it came down a fair amount. This tells me that the model performance improved.
#
#
# I would recommend the second model to stakeholders because it is more predictive than the first model.
#
#
# In my customized learning outcome, I mentioned wanting to be able to analyze hospitality booking data and gain value from it. This assignment certainly relates to that strongly.

# %% [markdown]
# ## 10. Reflect and Recommend
#
# ### Business framing:
# Ultimately, the value of your model comes from how well it can guide business decisions. Use your results to make real-world recommendations.
#
# ### In Your Response:
# 1. What business question did your model help answer?
# 2. What would you recommend to Airbnb or its hosts?
# 3. What could you do next to improve this model or make it more useful?
# 4. How does this relate to your customized learning outcome you created in canvas?

# %% [markdown]
# This model helped answer the business question of what predicts the price of Airbnb properties.
#
# I would recommend to Airbnb and its hosts to take a good look at communication scores and ratings overall to get a good idea of higher-priced, higher quality properties. These seem to have very high correlation. I would also let Airbnb know that higher review frequencies also equates to higher prices in general.
#
#
# To make this model more useful, I would refine the features even more, and delete more features that are not of any help in predicting price. I thought I did a good job at this at first, but I don't think I did. I think that shrinking the number of features used would be of help to the model. I would probably just pick the top ten features next time to work with.
#
#
# I mentioned wanting to be able to analyze large datasets and make recommendations to companies in my customized learning outcome I created in Canvas. This assignment has certainly helped me do that. This was a pretty interesting assignment because it gave me a good idea of how challenging a good regression model can be to create, and how important it is to pick great features to use in the model.

# %% [markdown]
# ## Submission Instructions
# ✅ Checklist:
# - All code cells run without error
# - All markdown responses are complete
# - Submit on Canvas as instructed

# %%
# !jupyter nbconvert --to html "assignment_11_regression.ipynb"
# Out:
# [NbConvertApp] Converting notebook assignment_11_regression.ipynb to html
# [NbConvertApp] Writing 365286 bytes to assignment_11_regression.html
